# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
from IPython.display import clear_output


class tickets_ava():
    
    
    tickets = []
    ticketCount = 10
    leftTicketCount = 0


def __init__(self, tickets):
        
        self.tickets = tickets
        self.ticketCount = len(tickets)
        self.leftticketCount = len(tickets)

def getticketCount(self):
        return self.ticketCount
    
                                            #def add_to_list(self,new_food):
                                         #  self.items.append(new_food)
                                        #  print("Added {}. {} items.".format(new_food, len(self.items)))
def getTicket(self,getTicket):
        self.tickets.append(getTicket)
        print("Added {}. tickets.".format(getTicket, len(self.tickets)))
                                                
        #return self.ticket

def getLeftTicketCount(self):
        return self.leftTicketCount

def pickTicketForParking(self):
        return TicketForParking
        
        self.leftTicketCount -= 1
        return self.tickets.pop(0)

def returnTheTicket(self, ticket):
        
        self.leftticketCount += 1
        self.tickets.insert(ticket.getticketId() - 1, ticket)
        
def parkedcars():


    while True:
        response = input("Tickets available, respond Yes or No if you're parking ")
#         hi_response = input("How many tickets ")
        if response.lower() == "done":
            break
        elif response.lower() == "no":
            print("Thank you for visiting us")
            break
        elif response.lower() == "yes":   
            hi_response = input("How many tickets ")
            continue
        elif response.lower() == "1":
            parkedcars.returnTheTicket()
        print("theres {} parking left")

parkedcars()

#         elif response

#             parkedcars.leftticketCount()
#             break
# Out:
# Tickets available, respond Yes or No if you're parking yes
# How many tickets 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
films = {
    "Finding Dory": {"Age": 3, "Tickets Available": 5},
    "Bourne": {"Age": 15, "Tickets Available": 10},
    "Tarzan": {"Age": 12, "Tickets Available": 7},
    "Ghost Busters": {"Age": 12, "Tickets Available": 2},
    "High School Musical 3": {"Age": 5, "Tickets Available": 25},
    "The Brother's Grimm": {"Age": 12, "Tickets Available": 3},
    "Harry Potter": {"Age": 11, "Tickets Available": 1}
    }

# Welcome customer to the cinema
print("Hello, welcome to our cinema. Today we have the following films on show:")

# Print out what films are available.
for x in films:
    print(x)

while True:

# What film would the customer like to see?
    choice = input("What film would you like to watch today?: ").strip().title()

# If their choice is in the films list, ask the customers age (convert to integer)
    if choice in films:
        print("That's a great choice, let's just check you're old enough to view this film")
        age = int(input("How old are you?: ").strip())

        
# If age is met, then see if there is enough tickets available
        if age < films[choice]["Age"]:
            print("Sorry you're not old enough to view that film, please pick another...")
        else:
            print("Lucky for you, you're old enough to view this masterpiece!")
            tickets = int(input("How many tickets would you like to purchase?: ").strip())

            
# Check if we have enough tickets.
            if films[choice]["Tickets Available"] >= tickets:
                print("Enjoy the film!")
                    
# Minus tickets requested from the number of tickets available
                films[choice]["Tickets Available"] = films[choice]["Tickets Available"] - tickets
                break

# If not enough tickets, ask customer if they would still like to purchase the remaining tickets or not.
            elif films[choice]["Tickets Available"] == 1 and films[choice]["Tickets Available"] < tickets:
                still_buy = input("Sorry we only have {0} ticket available right now, do you still want to purchase this ticket (y/n)? ".format(films[choice]["Tickets Available"])).strip().lower()
            elif films[choice]["Tickets Available"] > 1 and films[choice]["Tickets Available"] < tickets:
                still_buy = input("Sorry we only have {0} tickets available right now, do you still want to purchase these (y/n)? ".format(films[choice]["Tickets Available"])).strip().lower()

# If customer still wants to buy the tickets tell them to enjoy the film.                
                if still_buy == "y":
                    print("Thank you, I hope you enjoy the film!")
                    films[choice]["Tickets Available"] = 0
                    break
                else:
                    another_film = input("No worries, would you like to view another film (y/n)?: ").strip().lower()

# If customer doesn't want to view another film then break the loop
                    if another_film == "n":
                        print("No worries, I hope you have a great day")
                        break
# Out:
# Hello, welcome to our cinema. Today we have the following films on show:
# Finding Dory
# Bourne
# Tarzan
# Ghost Busters
# High School Musical 3
# The Brother's Grimm
# Harry Potter
# What film would you like to watch today?: Finding dory
# That's a great choice, let's just check you're old enough to view this film
# How old are you?: 15
# Lucky for you, you're old enough to view this masterpiece!
# How many tickets would you like to purchase?: 7
# Sorry we only have 5 tickets available right now, do you still want to purchase these (y/n)? n
# No worries, would you like to view another film (y/n)?: n
# No worries, I hope you have a great day

# %%
class Enemy():
    def __init__(self,ancestry,gear):
        self.enemy=ancestry
        self.weapon=gear
        self.hp=random.randrange(10,20)
        self.ac=random.randrange(12,20)
        self.alive=True

    def fight(self,tgt):
        print("You take a swing at the " + self.enemy + ".")
        hit=random.randrange(0,20)

        if self.alive and hit > self.ac:
            print("You hit the " + self.enemy + " for " + str(hit) + " damage!")
            self.hp = self.hp - hit
            print("The " + self.enemy + " has " + str(self.hp) + " HP remaining")
        else:
            print("You missed.")

        if self.hp < 1:
            self.alive=False

# game start
foe = Enemy("troll","great axe")
print("You meet a " + foe.enemy + " wielding a " + foe.weapon)

# main loop
while True:
   
    print("Type the a key and then RETURN to attack.")
       
    action=input()

    if action.lower() == "a":
        foe.fight(foe)
               
    if foe.alive == False:
        print("You have won...this time.")
        exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-73924327a7f1> in <module>
#      22
#      23 # game start
# ---> 24 foe = Enemy("troll","great axe")
#      25 print("You meet a " + foe.enemy + " wielding a " + foe.weapon)
#      26
#
# <ipython-input-107-73924327a7f1> in __init__(self, ancestry, gear)
#       3         self.enemy=ancestry
#       4         self.weapon=gear
# ----> 5         self.hp=random.randrange(10,20)
#       6         self.ac=random.randrange(12,20)
#       7         self.alive=True
#
# NameError: name 'random' is not defined
